# %% [markdown]
# # Lab 6: Hybrid Search with Neo4jContextProvider
#
# In this lab, you will combine vector and fulltext search into a single hybrid provider that captures both semantic similarity and keyword precision. This is the most versatile search mode — it catches results whether the user queries conceptually ("movies about dreams") or with specific terms ("Inception Christopher Nolan").
#
# ## What you will learn
#
# - How to configure `Neo4jContextProvider` with `index_type="hybrid"`
# - That hybrid search requires both a vector index and a fulltext index
# - How hybrid search combines scores from both search strategies
# - When hybrid search is the right choice

# %% [markdown]
# ## Setup

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)

provider_name = os.getenv("LLM_PROVIDER", "openai").lower()
if provider_name == "azure":
    assert os.getenv("AZURE_OPENAI_API_KEY"), "AZURE_OPENAI_API_KEY not set in .env file"
    assert os.getenv("AZURE_OPENAI_ENDPOINT"), "AZURE_OPENAI_ENDPOINT not set in .env file"
else:
    assert os.getenv("OPENAI_API_KEY"), "OPENAI_API_KEY not set in .env file"
assert os.getenv("NEO4J_URI"), "NEO4J_URI not set in .env file"
print("Environment loaded successfully")
# Out:
# Environment loaded successfully

# %% [markdown]
# ## Import Dependencies

# %%
from llm_provider import get_client, get_embedder
from agent_framework_neo4j import Neo4jContextProvider, Neo4jSettings

# %% [markdown]
# ## Load Settings and Create Embedder
#
# Hybrid search requires an embedder (for the vector component).

# %%
neo4j_settings = Neo4jSettings()
embedder = get_embedder()

# %% [markdown]
# ## Create the Hybrid Provider
#
# Hybrid search runs both vector and fulltext searches simultaneously and combines scores, so a movie can rank highly from semantic similarity, exact keyword matches, or both. Configure `Neo4jContextProvider` with:
# - `index_name` set to `neo4j_settings.vector_index_name` (for vector search)
# - `index_type="hybrid"`
# - `fulltext_index_name` set to `neo4j_settings.fulltext_index_name` (for fulltext search)
# - The embedder
# - `top_k=5`
# - A `context_prompt`
#
# The key difference from vector-only search is the `fulltext_index_name` parameter.

# %%
provider = Neo4jContextProvider(
    uri=neo4j_settings.uri,
    username=neo4j_settings.username,
    password=neo4j_settings.get_password(),
    index_name=neo4j_settings.vector_index_name,
    index_type="hybrid",
    fulltext_index_name=neo4j_settings.fulltext_index_name,
    embedder=embedder,
    top_k=5,
    context_prompt=(
        "## Movie Knowledge Graph Context\n"
        "Use the following movie information from the knowledge graph "
        "to answer questions:"
    ),
)

# %% [markdown]
# ## Run the Agent
#
# This query benefits from both search strategies:
# - **Fulltext search** finds plots containing "dream-sharing" and "technology" as literal terms
# - **Vector search** finds movies semantically related to dream and technology concepts

# %%
async with provider:
    client = get_client()

    agent = client.as_agent(
        name="movie-hybrid-agent",
        instructions=(
            "You are a movie recommendation assistant. Answer questions "
            "using the movie data provided in your context."
        ),
        context_providers=[provider],
    )

    session = agent.create_session()

    query = "Find movies about dream-sharing technology"
    print(f"User: {query}\n")
    print("Answer: ", end="", flush=True)
    response = await agent.run(query, session=session)
    print(response.text)
    print()
# Out:
# User: Find movies about dream-sharing technology
#
# Answer:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/neo4j_graphrag/embeddings/openai.py:72, in BaseOpenAIEmbeddings.embed_query(self, text, **kwargs)
#      71 try:
# ---> 72     response = self.client.embeddings.create(
#      73         input=text, model=self.model, **kwargs
#      74     )
#      75     embedding: list[float] = response.data[0].embedding
#
# File ~/.local/lib/python3.12/site-packages/openai/resources/embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145     ),
#     146     cast_to=CreateEmbeddingResponse,
#     147 )
#
# File ~/.local/lib/python3.12/site-packages/openai/_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.local/lib/python3.12/site-packages/openai/_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1069     log.debug("Re-raising status error")
# -> 1070     raise self._make_status_error_from_response(err.response) from None
#    1072 break
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************LZgA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}
#
# The above exception was the direct cause of the following exception:
#
# EmbeddingsGenerationError                 Traceback (most recent call last)
# Cell In[7], line 18
#      16 print(f"User: {query}\n")
#      17 print("Answer: ", end="", flush=True)
# ---> 18 response = await agent.run(query, session=session)
#      19 print(response.text)
#      20 print()
#
# File ~/.local/lib/python3.12/site-packages/agent_framework/_agents.py:831, in RawAgent.run.<locals>._run_non_streaming()
#     830 async def _run_non_streaming() -> AgentResponse[Any]:
# --> 831     ctx = await self._prepare_run_context(
#     832         messages=messages,
#     833         session=session,
#     834         tools=tools,
#     835         options=options,
#     836         kwargs=kwargs,
#     837     )
#     838     response = await self.client.get_response(  # type: ignore[call-overload]
#     839         messages=ctx["session_messages"],
#     840         stream=False,
#     841         options=ctx["chat_options"],
#     842         **ctx["filtered_kwargs"],
#     843     )
#     845     if not response:
#
# File ~/.local/lib/python3.12/site-packages/agent_framework/_agents.py:1017, in RawAgent._prepare_run_context(self, messages, session, tools, options, kwargs)
#    1014 if active_session is None and self.context_providers:
#    1015     active_session = AgentSession()
# -> 1017 session_context, chat_options = await self._prepare_session_and_messages(
#    1018     session=active_session,
#    1019     input_messages=input_messages,
#    1020     options=opts,
#    1021 )
#    1023 # Normalize tools
#    1024 normalized_tools = normalize_tools(tools_)
#
# File ~/.local/lib/python3.12/site-packages/agent_framework/_agents.py:1180, in RawAgent._prepare_session_and_messages(self, session, input_messages, options)
#    1178     if provider_session is None:
#    1179         raise RuntimeError("Provider session must be available when context providers are configured.")
# -> 1180     await provider.before_run(
#    1181         agent=self,  # type: ignore[arg-type]
#    1182         session=provider_session,
#    1183         context=session_context,
#    1184         state=provider_session.state.setdefault(provider.source_id, {}),
#    1185     )
#    1187 # Merge provider-contributed tools into chat_options
#    1188 if session_context.tools:
#
# File ~/.local/lib/python3.12/site-packages/agent_framework_neo4j/_provider.py:379, in Neo4jContextProvider.before_run(self, agent, session, context, state)
#     376     return
#     378 # Perform knowledge graph search using retriever
# --> 379 result = await self._execute_search(query_text)
#     380 if not result.items:
#     381     return
#
# File ~/.local/lib/python3.12/site-packages/agent_framework_neo4j/_provider.py:334, in Neo4jContextProvider._execute_search(self, query_text)
#     331     raise ValueError("Retriever not initialized")
#     333 # neo4j-graphrag retrievers are sync, wrap with asyncio.to_thread
# --> 334 return await asyncio.to_thread(
#     335     self._retriever.search,
#     336     query_text=query_text,
#     337     top_k=self._top_k,
#     338 )
#
# File /usr/local/lib/python3.12/asyncio/threads.py:25, in to_thread(func, *args, **kwargs)
#      23 ctx = contextvars.copy_context()
#      24 func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25 return await loop.run_in_executor(None, func_call)
#
# File /usr/local/lib/python3.12/concurrent/futures/thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File ~/.local/lib/python3.12/site-packages/neo4j_graphrag/retrievers/base.py:154, in Retriever.search(self, *args, **kwargs)
#     149 def search(self, *args: Any, **kwargs: Any) -> RetrieverResult:
#     150     """Search method. Call the `get_search_results` method that returns
#     151     a list of `neo4j.Record`, and format them using the function returned by
#     152     `get_result_formatter` to return `RetrieverResult`.
#     153     """
# --> 154     raw_result = self.get_search_results(*args, **kwargs)
#     155     formatter = self.get_result_formatter()
#     156     search_items = [formatter(record) for record in raw_result.records]
#
# File ~/.local/lib/python3.12/site-packages/neo4j_graphrag/retrievers/hybrid.py:202, in HybridRetriever.get_search_results(self, query_text, query_vector, top_k, effective_search_ratio, ranker, alpha)
#     198     if not self.embedder:
#     199         raise EmbeddingRequiredError(
#     200             "Embedding method required for text query."
#     201         )
# --> 202     query_vector = self.embedder.embed_query(query_text)
#     203     parameters["query_vector"] = query_vector
#     204 search_query, _ = get_search_query(
#     205     search_type=SearchType.HYBRID,
#     206     return_properties=self.return_properties,
#    (...)    210     alpha=validated_data.alpha,
#     211 )
#
# File ~/.local/lib/python3.12/site-packages/neo4j_graphrag/utils/rate_limit.py:251, in rate_limit_handler.<locals>.wrapper(self, *args, **kwargs)
#     248             raise to_retryable(e)
#     249         raise
# --> 251 return active_handler.handle_sync(inner_func)()
#
# File ~/.local/lib/python3.12/site-packages/tenacity/__init__.py:331, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     329 copy = self.copy()
#     330 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 331 return copy(f, *args, **kw)
#
# File ~/.local/lib/python3.12/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File ~/.local/lib/python3.12/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/.local/lib/python3.12/site-packages/tenacity/__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     391 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     392     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393         self._add_action_func(lambda rs: rs.outcome.result())
#     394         return
#     396     if self.after is not None:
#
# File /usr/local/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/local/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/.local/lib/python3.12/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/.local/lib/python3.12/site-packages/neo4j_graphrag/utils/rate_limit.py:239, in rate_limit_handler.<locals>.wrapper.<locals>.inner_func()
#     237 def inner_func() -> Any:
#     238     try:
# --> 239         return func(self, *args, **kwargs)
#     240     except Exception as e:
#     241         is_retryable = getattr(
#     242             active_handler, "is_retryable_exception", is_rate_limit_error
#     243         )
#
# File ~/.local/lib/python3.12/site-packages/neo4j_graphrag/embeddings/openai.py:78, in BaseOpenAIEmbeddings.embed_query(self, text, **kwargs)
#      76     return embedding
#      77 except Exception as e:
# ---> 78     raise EmbeddingsGenerationError(
#      79         f"Failed to generate embedding with OpenAI: {e}"
#      80     ) from e
#
# EmbeddingsGenerationError: Failed to generate embedding with OpenAI: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************LZgA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}

# %% [markdown]
# ## Summary
#
# Hybrid search combines vector and fulltext search by running both and merging the results. It requires a vector index, a fulltext index, and an embedder. This mode catches both semantic and keyword matches, making it the most versatile option when users mix conceptual and specific queries.
#
# **What's next:** In the next lab, you will configure the entity extraction pipeline that powers long-term memory, learning how entities are extracted, merged, and deduplicated in Neo4j.
