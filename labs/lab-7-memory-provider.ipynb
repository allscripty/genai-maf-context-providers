# %% [markdown]
# # Lab 7: Memory as a Context Provider
#
# In this lab, you will use `Neo4jMicrosoftMemory` to give an agent persistent memory that automatically retrieves relevant past messages, entities, and preferences before each turn, and stores new ones after. Memory turns the agent from stateless to stateful — it accumulates knowledge about users and conversations as a connected graph in Neo4j.
#
# ## What you will learn
#
# - How to configure `MemorySettings` with Neo4j connection details
# - How to create `Neo4jMicrosoftMemory` from a `MemoryClient`
# - How the memory context provider uses `before_run()` and `after_run()`
# - How to inspect stored memories with `search_memory()`

# %% [markdown]
# ## Setup

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)

provider_name = os.getenv("LLM_PROVIDER", "openai").lower()
if provider_name == "azure":
    assert os.getenv("AZURE_OPENAI_API_KEY"), "AZURE_OPENAI_API_KEY not set in .env file"
    assert os.getenv("AZURE_OPENAI_ENDPOINT"), "AZURE_OPENAI_ENDPOINT not set in .env file"
else:
    assert os.getenv("OPENAI_API_KEY"), "OPENAI_API_KEY not set in .env file"
assert os.getenv("NEO4J_URI"), "NEO4J_URI not set in .env file"
print("Environment loaded successfully")
# Out:
# Environment loaded successfully

# %% [markdown]
# ## Import Dependencies

# %%
from pydantic import SecretStr

from llm_provider import get_client, get_provider

from neo4j_agent_memory import MemoryClient, MemorySettings
from neo4j_agent_memory.integrations.microsoft_agent import (
    Neo4jMicrosoftMemory,
)

# %% [markdown]
# ## Configure Memory Settings
#
# Create a `MemorySettings` object with your Neo4j connection details. This reuses the same `NEO4J_URI`, `NEO4J_USERNAME`, and `NEO4J_PASSWORD` environment variables from previous labs.

# %%
if get_provider() == "azure":
    llm_model = os.getenv("AZURE_OPENAI_RESPONSES_DEPLOYMENT_NAME", "gpt-5-mini")
else:
    llm_model = os.getenv("OPENAI_RESPONSES_MODEL_ID", "gpt-5-mini")

settings = MemorySettings(
    neo4j={
        "uri": os.environ["NEO4J_URI"],
        "username": os.environ["NEO4J_USERNAME"],
        "password": SecretStr(os.environ["NEO4J_PASSWORD"]),
    },
    extraction={
        "enable_gliner": False,  # Disabled: downloads ~500MB model from HuggingFace, impractical in a workshop
        "llm_model": llm_model,
        "llm_temperature": 1.0,  # gpt-5-mini only supports temperature=1.0
    },
)

# %% [markdown]
# ## Connect the Memory Client
#
# `MemoryClient` supports explicit `connect()` and `close()` methods. Using explicit calls instead of `async with` lets us split the workflow across separate notebook cells.

# %%
memory_client = MemoryClient(settings)
await memory_client.connect()

# %% [markdown]
# ## Create Memory and Agent
#
# The memory provider gives the agent three types of persistent memory: **short-term** (recent messages found by semantic search), **long-term** (entities and preferences extracted from conversations), and **reasoning** (traces of past agent executions). Create `Neo4jMicrosoftMemory` with:
# - `include_short_term=True` — inject recent and semantically relevant past messages
# - `include_long_term=True` — inject extracted entities and preferences
# - `include_reasoning=True` — inject similar past reasoning traces
# - `extract_entities=True` — extract entities from messages after each turn
#
# Setting `extract_entities=True` runs the extraction pipeline configured in `MemorySettings` above after every agent turn. With the current settings, this uses two stages: **spaCy** for fast rule-based named entity recognition, then an **LLM fallback** for entities spaCy missed. (GLiNER, the third pipeline stage, is disabled to avoid downloading a ~500MB model during the workshop.) The next lab explores these extraction stages in detail.
#
# Pass `memory.context_provider` to the agent's `context_providers` list.

# %%
session_id = "movie-chat-session"

memory = Neo4jMicrosoftMemory.from_memory_client(
    memory_client=memory_client,
    session_id=session_id,
    include_short_term=True,
    include_long_term=True,
    include_reasoning=True,
    extract_entities=True,
)

client = get_client()

agent = client.as_agent(
    name="movie-memory-agent",
    instructions=(
        "You are a movie recommendation assistant with persistent "
        "memory. You remember what users have told you about their "
        "preferences, which movies you have discussed, and what "
        "you recommended in past sessions."
    ),
    context_providers=[memory.context_provider],
)

# %% [markdown]
# ## Run a Multi-Turn Conversation
#
# Test the memory provider with a 3-turn conversation:
#
# 1. **Turn 1** — The user states a preference. `after_run()` saves the message and extracts entities.
# 2. **Turn 2** — The user asks what they said. `before_run()` retrieves the previous message and injects it.
# 3. **Turn 3** — The agent has both conversation history and extracted preferences available.

# %%
session = agent.create_session()

queries = [
    "I really enjoy sci-fi movies, especially ones about time travel.",
    "What did I say my favorite genre was?",
    "Can you recommend something I might like?",
]

for query in queries:
    print(f"\nUser: {query}")
    response = await agent.run(query, session=session)
    print(f"Assistant: {response.text}")
# Out:
# User: I really enjoy sci-fi movies, especially ones about time travel.
# Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `HAS_MESSAGE` does not exist in database `neo4j`. Verify that the spelling is correct.', position=<SummaryInputPosition line=2, column=49, offset=49>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 49, 'line': 2, 'column': 49}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: '\nMATCH (c:Conversation {id: $conversation_id})-[:HAS_MESSAGE]->(m:Message)\nRETURN m\nORDER BY m.timestamp ASC\nLIMIT $limit\n'
# Error saving messages to memory: Failed to generate embedding: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************LZgA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.12/site-packages/neo4j_agent_memory/embeddings/openai.py", line 78, in embed
#     response = await client.embeddings.create(**kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.12/site-packages/openai/resources/embeddings.py", line 259, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.12/site-packages/openai/_base_client.py", line 1884, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.12/site-packages/openai/_base_client.py", line 1669, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************LZgA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/vscode/.local/lib/python3.12/site-packages/neo4j_agent_memory/integrations/microsoft_agent/context_provider.py", line 243, in after_run
#     await self._client.short_term.add_message(
#   File "/home/vscode/.local/lib/python3.12/site-packages/neo4j_agent_memory/memory/short_term.py", line 521, in add_message
#     embedding = await self._embedder.embed(content)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/vscode/.local/lib/python3.12/site-packages/neo4j_agent_memory/embeddings/openai.py", line 81, in embed
#     raise EmbeddingError(f"Failed to generate embedding: {e}") from e
# neo4j_agent_memory.core.exceptions.EmbeddingError: Failed to generate embedding: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************LZgA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}
# Assistant: Awesome — I’ll remember you like sci‑fi, especially time travel.
#
# Here are some time‑travel sci‑fi picks across different styles (short notes on why you might enjoy each):
#
# - Back to the Future (1985) — Classic, fun adventure with clever paradox play and great characters.
# - Primer (2004) — Ultra‑hard, low‑budget, mind‑bending and realistic-seeming tech; for puzzle lovers.
# - Predestination (2014) — Tight, twisty plot about identity and paradoxes; very satisfying if you like narrative puzzles.
# - Looper (2012) — Gritty, action‑driven with emotional stakes and interesting moral questions.
# - 12 Monkeys (1995) — Dark, cerebral time‑travel thriller with great performances and an uncertain reality vibe.
# - Edge of Tomorrow (2014) — Time loop + big‑budget action; great if you want spectacle with a repeating‑day mechanic.
# - Source Code (2011) — Fast, tense techno‑thriller focusing on a repeating short window to change outcomes.
# - Timecrimes (Los Cronocrímenes) (2007) — Low‑budget Spanish thriller with tight, escalating paradoxes.
# - Donnie Darko (2001) — Surreal, atmospheric and culty — more psychological/time‑bent than hard sci‑fi.
# - About Time (2013) — If you want something gentler: a time‑travel romance that focuses on life choices and feelings.
#
# Want me to:
# - Narrow this list to a particular tone (action, mind‑bending, dark, romantic)?
# - Recommend where to stream any of these?
# - Save specific favorites in your profile so I remember them later?
#
# User: What did I say my favorite genre was?
# Received notification from DBMS server: <GqlStatusObject gql_status='01N51', status_description='warn: relationship type does not exist. The relationship type `HAS_MESSAGE` does not exist in database `neo4j`. Verify that the spelling is correct.', position=<SummaryInputPosition line=2, column=49, offset=49>, raw_classification='UNRECOGNIZED', classification=<NotificationClassification.UNRECOGNIZED: 'UNRECOGNIZED'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'UNRECOGNIZED', '_severity': 'WARNING', '_position': {'offset': 49, 'line': 2, 'column': 49}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: '\nMATCH (c:Conversation {id: $conversation_id})-[:HAS_MESSAGE]->(m:Message)\nRETURN m\nORDER BY m.timestamp ASC\nLIMIT $limit\n'
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/agent_framework/openai/_responses_client.py:339, in RawOpenAIResponsesClient._inner_get_response.<locals>._get_response()
#     338     else:
# --> 339         response = await client.responses.create(stream=False, **run_options)
#     340 except Exception as ex:
#
# File ~/.local/lib/python3.12/site-packages/openai/resources/responses/responses.py:2561, in AsyncResponses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#    2522 async def create(
#    2523     self,
#    2524     *,
#    (...)   2559     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    2560 ) -> Response | AsyncStream[ResponseStreamEvent]:
# -> 2561     return await self._post(
#    2562         "/responses",
#    2563         body=await async_maybe_transform(
#    2564             {
#    2565                 "background": background,
#    2566                 "context_management": context_management,
#    2567                 "conversation": conversation,
#    2568                 "include": include,
#    2569                 "input": input,
#    2570                 "instructions": instructions,
#    2571                 "max_output_tokens": max_output_tokens,
#    2572                 "max_tool_calls": max_tool_calls,
#    2573                 "metadata": metadata,
#    2574                 "model": model,
#    2575                 "parallel_tool_calls": parallel_tool_calls,
#    2576                 "previous_response_id": previous_response_id,
#    2577                 "prompt": prompt,
#    2578                 "prompt_cache_key": prompt_cache_key,
#    2579                 "prompt_cache_retention": prompt_cache_retention,
#    2580                 "reasoning": reasoning,
#    2581                 "safety_identifier": safety_identifier,
#    2582                 "service_tier": service_tier,
#    2583                 "store": store,
#    2584                 "stream": stream,
#    2585                 "stream_options": stream_options,
#    2586                 "temperature": temperature,
#    2587                 "text": text,
#    2588                 "tool_choice": tool_choice,
#    2589                 "tools": tools,
#    2590                 "top_logprobs": top_logprobs,
#    2591                 "top_p": top_p,
#    2592                 "truncation": truncation,
#    2593                 "user": user,
#    2594             },
#    2595             response_create_params.ResponseCreateParamsStreaming
#    2596             if stream
#    2597             else response_create_params.ResponseCreateParamsNonStreaming,
#    2598         ),
#    2599         options=make_request_options(
#    2600             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2601         ),
#    2602         cast_to=Response,
#    2603         stream=stream or False,
#    2604         stream_cls=AsyncStream[ResponseStreamEvent],
#    2605     )
#
# File ~/.local/lib/python3.12/site-packages/openai/_base_client.py:1884, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1881 opts = FinalRequestOptions.construct(
#    1882     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1883 )
# -> 1884 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/.local/lib/python3.12/site-packages/openai/_base_client.py:1669, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1668     log.debug("Re-raising status error")
# -> 1669     raise self._make_status_error_from_response(err.response) from None
#    1671 break
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************LZgA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}
#
# The above exception was the direct cause of the following exception:
#
# ChatClientException                       Traceback (most recent call last)
# Cell In[12], line 11
#       9 for query in queries:
#      10     print(f"\nUser: {query}")
# ---> 11     response = await agent.run(query, session=session)
#      12     print(f"Assistant: {response.text}")
#
# File ~/.local/lib/python3.12/site-packages/agent_framework/_agents.py:838, in RawAgent.run.<locals>._run_non_streaming()
#     830 async def _run_non_streaming() -> AgentResponse[Any]:
#     831     ctx = await self._prepare_run_context(
#     832         messages=messages,
#     833         session=session,
#    (...)    836         kwargs=kwargs,
#     837     )
# --> 838     response = await self.client.get_response(  # type: ignore[call-overload]
#     839         messages=ctx["session_messages"],
#     840         stream=False,
#     841         options=ctx["chat_options"],
#     842         **ctx["filtered_kwargs"],
#     843     )
#     845     if not response:
#     846         raise AgentInvalidResponseException("Chat client did not return a response.")
#
# File ~/.local/lib/python3.12/site-packages/agent_framework/_tools.py:2139, in FunctionInvocationLayer.get_response.<locals>._get_response()
#    2136 errors_in_a_row = approval_result["errors_in_a_row"]
#    2137 total_function_calls += approval_result.get("function_call_count", 0)
# -> 2139 response = await super_get_response(
#    2140     messages=prepped_messages,
#    2141     stream=False,
#    2142     options=mutable_options,
#    2143     **filtered_kwargs,
#    2144 )
#    2146 if response.conversation_id is not None:
#    2147     _update_conversation_id(kwargs, response.conversation_id, mutable_options)
#
# File ~/.local/lib/python3.12/site-packages/agent_framework/openai/_responses_client.py:341, in RawOpenAIResponsesClient._inner_get_response.<locals>._get_response()
#     339         response = await client.responses.create(stream=False, **run_options)
#     340 except Exception as ex:
# --> 341     self._handle_request_error(ex)
#     342 return self._parse_response_from_openai(response, options=validated_options)
#
# File ~/.local/lib/python3.12/site-packages/agent_framework/openai/_responses_client.py:266, in RawOpenAIResponsesClient._handle_request_error(self, ex)
#     261 if isinstance(ex, BadRequestError) and ex.code == "content_filter":
#     262     raise OpenAIContentFilterException(
#     263         f"{type(self)} service encountered a content error: {ex}",
#     264         inner_exception=ex,
#     265     ) from ex
# --> 266 raise ChatClientException(
#     267     f"{type(self)} service failed to complete the prompt: {ex}",
#     268     inner_exception=ex,
#     269 ) from ex
#
# ChatClientException: <class 'agent_framework.openai._responses_client.OpenAIResponsesClient'> service failed to complete the prompt: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************LZgA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}

# %% [markdown]
# ## Inspect Stored Memories
#
# After the conversation, verify what the provider stored by searching the memory directly. Messages, entities, and preferences are stored as connected nodes in Neo4j — the memory is a knowledge graph the agent builds over time.

# %%
results = await memory.search_memory(
    query="sci-fi movies",
    include_messages=True,
    include_entities=True,
    include_preferences=True,
    limit=5,
)

print("Messages:", results.get("messages", []))
print("Entities:", results.get("entities", []))
print("Preferences:", results.get("preferences", []))
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/neo4j_agent_memory/embeddings/openai.py:78, in OpenAIEmbedder.embed(self, text)
#      76     kwargs["dimensions"] = self._requested_dimensions
# ---> 78 response = await client.embeddings.create(**kwargs)
#      79 return response.data[0].embedding
#
# File ~/.local/lib/python3.12/site-packages/openai/resources/embeddings.py:259, in AsyncEmbeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     257     return obj
# --> 259 return await self._post(
#     260     "/embeddings",
#     261     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     262     options=make_request_options(
#     263         extra_headers=extra_headers,
#     264         extra_query=extra_query,
#     265         extra_body=extra_body,
#     266         timeout=timeout,
#     267         post_parser=parser,
#     268     ),
#     269     cast_to=CreateEmbeddingResponse,
#     270 )
#
# File ~/.local/lib/python3.12/site-packages/openai/_base_client.py:1884, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1881 opts = FinalRequestOptions.construct(
#    1882     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1883 )
# -> 1884 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/.local/lib/python3.12/site-packages/openai/_base_client.py:1669, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1668     log.debug("Re-raising status error")
# -> 1669     raise self._make_status_error_from_response(err.response) from None
#    1671 break
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************LZgA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}
#
# The above exception was the direct cause of the following exception:
#
# EmbeddingError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 results = await memory.search_memory(
#       2     query="sci-fi movies",
#       3     include_messages=True,
#       4     include_entities=True,
#       5     include_preferences=True,
#       6     limit=5,
#       7 )
#       9 print("Messages:", results.get("messages", []))
#      10 print("Entities:", results.get("entities", []))
#
# File ~/.local/lib/python3.12/site-packages/neo4j_agent_memory/integrations/microsoft_agent/memory.py:287, in Neo4jMicrosoftMemory.search_memory(self, query, include_messages, include_entities, include_preferences, limit)
#     284 results: dict[str, list[Any]] = {}
#     286 if include_messages:
# --> 287     messages = await self._client.short_term.search_messages(
#     288         query=query,
#     289         session_id=self._session_id,
#     290         limit=limit,
#     291     )
#     292     results["messages"] = [
#     293         {
#     294             "role": m.role.value if hasattr(m.role, "value") else str(m.role),
#    (...)    298         for m in messages
#     299     ]
#     301 if include_entities:
#
# File ~/.local/lib/python3.12/site-packages/neo4j_agent_memory/memory/short_term.py:653, in ShortTermMemory.search_messages(self, query, session_id, limit, threshold, metadata_filters)
#     650 if self._embedder is None:
#     651     return []
# --> 653 query_embedding = await self._embedder.embed(query)
#     655 # Build metadata filter clause if provided
#     656 # Use JSON string matching which doesn't require APOC
#     657 metadata_clause, metadata_params = _build_metadata_filter_clause_json(
#     658     metadata_filters or {}, metadata_prop="m.metadata"
#     659 )
#
# File ~/.local/lib/python3.12/site-packages/neo4j_agent_memory/embeddings/openai.py:81, in OpenAIEmbedder.embed(self, text)
#      79     return response.data[0].embedding
#      80 except Exception as e:
# ---> 81     raise EmbeddingError(f"Failed to generate embedding: {e}") from e
#
# EmbeddingError: Failed to generate embedding: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************LZgA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}

# %% [markdown]
# ## Close the Connection
#
# Always close the `MemoryClient` when you are done.

# %%
await memory_client.close()
print("Connection closed")
# Out:
# Connection closed

# %% [markdown]
# ## Summary
#
# `Neo4jMicrosoftMemory` provides a context provider that retrieves relevant memories in `before_run()` and stores new messages and extracted entities in `after_run()`. The agent gets persistent memory across turns and sessions without calling any tools.
#
# **What's next:** In the next lab, you will explore the entity extraction pipeline that powers the automatic extraction you saw in this lab — learning how spaCy, GLiNER, and LLM fallback stages work together to pull structured entities from conversation text.
